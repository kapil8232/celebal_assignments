# %% [markdown]
# ## Step 1: Import Libraries

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql import *
from pyspark.sql import SparkSession
from delta.tables import *

# %% [markdown]
# ## Step 2: Define Project Paths

# %%
base_path="/Volumes/dbacademy/default/data/retail_delta_project"
batch_path="/Volumes/dbacademy/default/data/retail_delta_project/datasets/batch"
incremental_path="/Volumes/dbacademy/default/data/retail_delta_project/datasets/incremental"

# %% [markdown]
# ## Step 3: Output Paths

# %%
bronze_path="/Volumes/dbacademy/default/data/retail_delta_project/bronze"
silver_path="/Volumes/dbacademy/default/data/retail_delta_project/silver"
gold_path="/Volumes/dbacademy/default/data/retail_delta_project/gold"

# %% [markdown]
# ## Step 4: Verify Dataset

# %%
display(dbutils.fs.ls(batch_path))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Step 5: Check Incremental Folder

# %%
display(dbutils.fs.ls(incremental_path))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/dbacademy/default/data/retail_delta_project/datasets/incremental/day_2026-04-24/</td><td>day_2026-04-24/</td><td>0</td><td>1783500172145</td></tr><tr><td>dbfs:/Volumes/dbacademy/default/data/retail_delta_project/datasets/incremental/day_2026-04-25/</td><td>day_2026-04-25/</td><td>0</td><td>1783500172145</td></tr><tr><td>dbfs:/Volumes/dbacademy/default/data/retail_delta_project/datasets/incremental/day_2026-04-26/</td><td>day_2026-04-26/</td><td>0</td><td>1783500172145</td></tr></tbody></table></div>

# %% [markdown]
# ## Step 6: Create Output Directories

# %%
dbutils.fs.mkdirs(bronze_path)
dbutils.fs.mkdirs(silver_path)
dbutils.fs.mkdirs(gold_path)
# Out:
# True

# %% [markdown]
# ## Step 7: Print Paths

# %%
print("Batch Path :", batch_path)
print("Incremental Path :", incremental_path)
print("Bronze Path :", bronze_path)
print("Silver Path :", silver_path)
print("Gold Path :", gold_path)
# Out:
# Batch Path : /Volumes/dbacademy/default/data/retail_delta_project/datasets/batch
# Incremental Path : /Volumes/dbacademy/default/data/retail_delta_project/datasets/incremental
# Bronze Path : /Volumes/dbacademy/default/data/retail_delta_project/bronze
# Silver Path : /Volumes/dbacademy/default/data/retail_delta_project/silver
# Gold Path : /Volumes/dbacademy/default/data/retail_delta_project/gold
